# %% [markdown]
# #### Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd

# %%
ser = pd.Series([4,8,15,16,23,42])
ser
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %% [markdown]
# #### Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %%
lst = [1,2,3,4,3,2,3,2,4,5]
ser = pd.Series(lst)
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    3
# 5    2
# 6    3
# 7    2
# 8    4
# 9    5
# dtype: int64

# %% [markdown]
# #### Q3. Create a Pandas DataFrame that contains the following data:
#
# | Name |Age | Gender |
# |----|-------|------|
# |Alice | 25 | Female |
# |Bob | 30 | Male |
# |Claire | 27 | Female |
# #### Then, print the DataFrame.

# %%
df = pd.DataFrame({'Name' : ['Alice', 'Bob', 'Claire'],
                  'Bob' : [25, 30, 27],
                  'Gender' : ['Female', 'Male', 'Female']
                  })
df
# Out:
#      Name  Bob  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# #### Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.

# %% [markdown]
# * A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# * A Series only has one data column, whereas a single-column DataFrame contains both a data column and an index. The labels for the data are contained in the index, which is a second column.
#
# * There are certain distinctions in the extra features that a Series and a single-column DataFrame offer, despite the fact that they share many common functionalities. Additional features like filtering, merging, and joining is accessible in a single-column DataFrame but not in a Series.
#
# * When you only have one column of data and don't need to do any operations that call for a DataFrame, you should generally utilize a Pandas Series. When you require the extra features of a DataFrame, such as filtering, merging, and joining, a single-column DataFrame should be employed.

# %%
ser = pd.Series([4,8,15,16,23,42])
ser
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
df = pd.DataFrame({'Name' : ['Alice', 'Bob', 'Claire'],
                  'Bob' : [25, 30, 27],
                  'Gender' : ['Female', 'Male', 'Female']
                  })
df
# Out:
#      Name  Bob  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# #### Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?

# %%
import pandas as pd
df1 = pd.read_csv("services.csv")

# %%
# df1.head() - This function helps you to get the first few rows of the dataset. By default, it returns the first 5 rows.

df1.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
# df1.tail() - This function helps you to get the last few rows of the dataset. By default, it returns the last 5 rows.

df1.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
# df1.describe() - This function returns descriptive statistics about the data. This includes minimum, maximum, mean (central tendency), 
# standard deviation (dispersion) of the values in numerical columns, and the count of all non-null values in the data, as shown below.

df1.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
# df1.unique() - This function returns the list of unique values in a column or series. Instead of applying on complete DataFrame, it works only on the selected single column.

df1['status'].unique()
# Out:
# array(['active', 'defunct', 'inactive'], dtype=object)

# %%
#df1.isnull() - This function helps you to check if there in which row and which column your data has missing values

# %%
df1['location_id'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# Name: location_id, dtype: bool

# %% [markdown]
# #### Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %% [markdown]
# DataFrame and Panel are mutable.

# %% [markdown]
# #### Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
courses = pd.Series(["Spark","PySpark","Hadoop"], name='courses')
fees = pd.Series([22000,25000,23000], name='fees')
discount  = pd.Series([1000,2300,1000],name='discount')

df=pd.concat([courses,fees,discount],axis=1)
print(df)
# Out:
#    courses   fees  discount
# 0    Spark  22000      1000
# 1  PySpark  25000      2300
# 2   Hadoop  23000      1000
