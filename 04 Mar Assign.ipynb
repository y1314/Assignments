# %% [markdown]
# #### Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a scatter plot for age and fare columns in the titanic dataset.

# %%
import seaborn as sns
tit = sns.load_dataset('titanic')
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x = tit.age, y = tit.fare, mode = 'markers'))
fig.show()

# %% [markdown]
# ![newplot.png](attachment:c629d2ba-ce1c-43bb-8ae3-8ad2f06682ac.png)

# %% [markdown]
# #### Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
import plotly.express as px
df = px.data.tips()
fig = px.box(df, x="time", y="total_bill")
fig.show()

# %% [markdown]
# ![newplot (3).png](attachment:94b20b9c-78e0-4d09-a8c7-c4f1a1cc36a4.png)

# %% [markdown]
# #### Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day" column with the color parameter.

# %%
import plotly.express as px
df = px.data.tips()

fig = px.bar(df, x="sex", y="total_bill", color = 'day',  pattern_shape="smoker")
fig.show()

# %% [markdown]
# ![newplot (4).png](attachment:b7f68617-5b42-4b34-b506-82152e571899.png)

# %% [markdown]
# #### Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for the color parameter.
# #### Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the dimensions parameter.

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_matrix(df,
    dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    color="species")
fig.show()

# %% [markdown]
# ![newplot (5).png](attachment:d9bd90f2-15a9-47f9-bd28-aa08e35b4162.png)

# %% [markdown]
# #### Q5. What is Distplot? Using Plotly express, plot a distplot.

# %% [markdown]
# Ans - We use a displot (also known as a distribution plot) to represent data in histogram form. It is a univariant set of collected data, which means the data distribution of one variable will be shown against another variable. In Python, we use the Seaborn library with Matplotlib for data visualization.

# %%
import plotly.figure_factory as ff
import numpy as np
np.random.seed(1)

x = np.random.randn(1000)
hist_data = [x]
group_labels = ['distplot'] # name of the dataset

fig = ff.create_distplot(hist_data, group_labels)
fig.show()

# %% [markdown]
# ![newplot (2).png](attachment:f524c796-922e-4344-9e5b-78b2f5e5e5f4.png)
